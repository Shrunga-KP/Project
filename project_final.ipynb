# %%
import pandas as pd
from scipy.stats import pearsonr
import random

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Import dataset

# %%
import pandas as pd
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Data/Boston.csv")
df
# Out:
#      Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0             1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1             2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2             3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3             4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4             5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
# ..          ...      ...   ...    ...   ...    ...    ...   ...     ...  ...
# 501         502  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1
# 502         503  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1
# 503         504  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1
# 504         505  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1
# 505         506  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1
#
#      tax  ptratio   black  lstat  medv
# ...

# %% [markdown]
# Correlation matrix

# %%
import pandas as pd
correlation_matrix = df.corr()

print("Pearson Correlation Coefficient Matrix:")
print(correlation_matrix)
# Out:
# Pearson Correlation Coefficient Matrix:
#             Unnamed: 0      crim        zn     indus      chas       nox  \
# Unnamed: 0    1.000000  0.407407 -0.103393  0.399439 -0.003759  0.398736
# crim          0.407407  1.000000 -0.200469  0.406583 -0.055892  0.420972
# zn           -0.103393 -0.200469  1.000000 -0.533828 -0.042697 -0.516604
# indus         0.399439  0.406583 -0.533828  1.000000  0.062938  0.763651
# chas         -0.003759 -0.055892 -0.042697  0.062938  1.000000  0.091203
# nox           0.398736  0.420972 -0.516604  0.763651  0.091203  1.000000
# rm           -0.079971 -0.219247  0.311991 -0.391676  0.091251 -0.302188
# age           0.203784  0.352734 -0.569537  0.644779  0.086518  0.731470
# dis          -0.302211 -0.379670  0.664408 -0.708027 -0.099176 -0.769230
# rad           0.686002  0.625505 -0.311948  0.595129 -0.007368  0.611441
# tax           0.666626  0.582764 -0.314563  0.720760 -0.035587  0.668023
# ...

# %% [markdown]
# Column descriptions

# %%
column_descriptions = {
    'crim': 'Per capita crime rate by town',
    'zn': 'Proportion of residential land zoned for large lots',
    'indus': 'Proportion of non-retail business acres per town',
    'chas': 'Charles River dummy variable (1 if tract bounds river, 0 otherwise)',
    'nox': 'Nitrogen oxide concentration (parts per 10 million)',
    'rm': 'Average number of rooms per dwelling',
    'age': 'Proportion of owner-occupied units built before 1940',
    'dis': 'Weighted distance to employment centers',
    'rad': 'Index of accessibility to radial highways',
    'tax': 'Property tax rate',
    'ptratio': 'Pupil-teacher ratio',
    'black': 'Proportion of residents of African American descent',
    'lstat': 'Percentage of lower status population',
    'medv': 'Median value of owner-occupied homes'
}

# %% [markdown]
# Finding correlation for 50% dataset

# %%
num_rows_to_select = int(len(df) * 0.5)
random.seed(42)  # Set a seed for reproducibility

max_correlation_coefficients = {}  # Initialize an empty dictionary to store max coefficients

for col in df.columns[1:-1]:  # Iterate through all columns except the last one ('medv') #medv(target variable)
    max_correlation_coefficient = float("-inf")  # Initialize with negative infinity
    for _ in range(1000):  # Run 1000 iterations
        selected_rows = random.sample(range(len(df)), num_rows_to_select) #Randomly samples rows without replacement

        col_data = df.loc[selected_rows, col].to_numpy() #Extracts the values of the current feature for the selected rows
        medv_data = df.loc[selected_rows, 'medv'].to_numpy() #Extracts the values of the target variable ('medv') for the selected rows

        correlation_coefficient, p_value = pearsonr(col_data, medv_data) #Calculates the Pearson correlation coefficient

        # Update max_correlation_coefficient if a higher value is found
        if correlation_coefficient > max_correlation_coefficient:
            max_correlation_coefficient = correlation_coefficient

    max_correlation_coefficients[column_descriptions[col]] = max_correlation_coefficient

print("Maximum Pearson Correlation Coefficients:")
for col, max_corr in max_correlation_coefficients.items():
    print(f"{col} vs. medv: {max_corr}")
# Out:
# Maximum Pearson Correlation Coefficients:
# Per capita crime rate by town vs. medv: -0.29559750359849585
# Proportion of residential land zoned for large lots vs. medv: 0.4995745999956171
# Proportion of non-retail business acres per town vs. medv: -0.3487397359171816
# Charles River dummy variable (1 if tract bounds river, 0 otherwise) vs. medv: 0.3452960411072694
# Nitrogen oxide concentration (parts per 10 million) vs. medv: -0.32893156769449816
# Average number of rooms per dwelling vs. medv: 0.8037084020269109
# Proportion of owner-occupied units built before 1940 vs. medv: -0.2501552819425838
# Weighted distance to employment centers vs. medv: 0.4141156161225752
# Index of accessibility to radial highways vs. medv: -0.2699527245053617
# Property tax rate vs. medv: -0.34241945065507373
# Pupil-teacher ratio vs. medv: -0.36814696099305705
# Proportion of residents of African American descent vs. medv: 0.41797427255248093
# ...

# %% [markdown]
# Finding correlation for 60% dataset

# %%
num_rows_to_select = int(len(df) * 0.6)
random.seed(42)  # Set a seed for reproducibility

max_correlation_coefficients = {}  # Initialize an empty dictionary to store max coefficients

for col in df.columns[1:-1]:  # Iterate through all columns except the last one ('medv')
    max_correlation_coefficient = float("-inf")  # Initialize with negative infinity
    for _ in range(1000):  # Run 1000 iterations
        selected_rows = random.sample(range(len(df)), num_rows_to_select)

        col_data = df.loc[selected_rows, col].to_numpy()
        medv_data = df.loc[selected_rows, 'medv'].to_numpy()

        correlation_coefficient, p_value = pearsonr(col_data, medv_data)

        # Update max_correlation_coefficient if a higher value is found
        if correlation_coefficient > max_correlation_coefficient:
            max_correlation_coefficient = correlation_coefficient

    max_correlation_coefficients[column_descriptions[col]] = max_correlation_coefficient

print("Maximum Pearson Correlation Coefficients:")
for col, max_corr in max_correlation_coefficients.items():
    print(f"{col} vs. medv: {max_corr}")
# Out:
# Maximum Pearson Correlation Coefficients:
# Per capita crime rate by town vs. medv: -0.31034609880781316
# Proportion of residential land zoned for large lots vs. medv: 0.46652438242172967
# Proportion of non-retail business acres per town vs. medv: -0.3902913423408884
# Charles River dummy variable (1 if tract bounds river, 0 otherwise) vs. medv: 0.295200621537342
# Nitrogen oxide concentration (parts per 10 million) vs. medv: -0.34029222710882945
# Average number of rooms per dwelling vs. medv: 0.8045927632369039
# Proportion of owner-occupied units built before 1940 vs. medv: -0.27689039183208763
# Weighted distance to employment centers vs. medv: 0.3668746978535132
# Index of accessibility to radial highways vs. medv: -0.2809010658896799
# Property tax rate vs. medv: -0.35343393923517663
# Pupil-teacher ratio vs. medv: -0.40264007624461323
# Proportion of residents of African American descent vs. medv: 0.4024566357716449
# ...

# %% [markdown]
# Finding correlation for 70% dataset

# %%
num_rows_to_select = int(len(df) * 0.7)
random.seed(42)  # Set a seed for reproducibility

max_correlation_coefficients = {}  # Initialize an empty dictionary to store max coefficients

for col in df.columns[1:-1]:  # Iterate through all columns except the last one ('medv')
    max_correlation_coefficient = float("-inf")  # Initialize with negative infinity
    for _ in range(1000):  # Run 1000 iterations
        selected_rows = random.sample(range(len(df)), num_rows_to_select)

        col_data = df.loc[selected_rows, col].to_numpy()
        medv_data = df.loc[selected_rows, 'medv'].to_numpy()

        correlation_coefficient, p_value = pearsonr(col_data, medv_data)

        # Update max_correlation_coefficient if a higher value is found
        if correlation_coefficient > max_correlation_coefficient:
            max_correlation_coefficient = correlation_coefficient

    max_correlation_coefficients[column_descriptions[col]] = max_correlation_coefficient

print("Maximum Pearson Correlation Coefficients:")
for col, max_corr in max_correlation_coefficients.items():
    print(f"{col} vs. medv: {max_corr}")
# Out:
# Maximum Pearson Correlation Coefficients:
# Per capita crime rate by town vs. medv: -0.3288519463601214
# Proportion of residential land zoned for large lots vs. medv: 0.43951590443684624
# Proportion of non-retail business acres per town vs. medv: -0.3936799122952218
# Charles River dummy variable (1 if tract bounds river, 0 otherwise) vs. medv: 0.281046475700835
# Nitrogen oxide concentration (parts per 10 million) vs. medv: -0.36209207954277445
# Average number of rooms per dwelling vs. medv: 0.7861977027630673
# Proportion of owner-occupied units built before 1940 vs. medv: -0.29176834220345815
# Weighted distance to employment centers vs. medv: 0.3398447927327532
# Index of accessibility to radial highways vs. medv: -0.30085968139293007
# Property tax rate vs. medv: -0.3793697038273842
# Pupil-teacher ratio vs. medv: -0.4362237352010012
# Proportion of residents of African American descent vs. medv: 0.3829015288313587
# ...

# %% [markdown]
# Finding correlation for 80% dataset

# %%
num_rows_to_select = int(len(df) * 0.8)
random.seed(42)  # Set a seed for reproducibility

max_correlation_coefficients = {}  # Initialize an empty dictionary to store max coefficients

for col in df.columns[1:-1]:  # Iterate through all columns except the last one ('medv')
    max_correlation_coefficient = float("-inf")  # Initialize with negative infinity
    for _ in range(1000):  # Run 1000 iterations
        selected_rows = random.sample(range(len(df)), num_rows_to_select)

        col_data = df.loc[selected_rows, col].to_numpy()
        medv_data = df.loc[selected_rows, 'medv'].to_numpy()

        correlation_coefficient, p_value = pearsonr(col_data, medv_data)

        # Update max_correlation_coefficient if a higher value is found
        if correlation_coefficient > max_correlation_coefficient:
            max_correlation_coefficient = correlation_coefficient

    max_correlation_coefficients[column_descriptions[col]] = max_correlation_coefficient

print("Maximum Pearson Correlation Coefficients:")
for col, max_corr in max_correlation_coefficients.items():
    print(f"{col} vs. medv: {max_corr}")
# Out:
# Maximum Pearson Correlation Coefficients:
# Per capita crime rate by town vs. medv: -0.34560511795752674
# Proportion of residential land zoned for large lots vs. medv: 0.42394847416679277
# Proportion of non-retail business acres per town vs. medv: -0.4289245332918479
# Charles River dummy variable (1 if tract bounds river, 0 otherwise) vs. medv: 0.25985387820523215
# Nitrogen oxide concentration (parts per 10 million) vs. medv: -0.37376283854441317
# Average number of rooms per dwelling vs. medv: 0.7808339078896694
# Proportion of owner-occupied units built before 1940 vs. medv: -0.31432409694766433
# Weighted distance to employment centers vs. medv: 0.3108692485955289
# Index of accessibility to radial highways vs. medv: -0.32648654316603914
# Property tax rate vs. medv: -0.41429145187859046
# Pupil-teacher ratio vs. medv: -0.44870626152176435
# Proportion of residents of African American descent vs. medv: 0.3733391795468268
# ...

# %% [markdown]
# Finding correlation for 90% dataset

# %%
num_rows_to_select = int(len(df) * 0.9)
random.seed(42)  # Set a seed for reproducibility

max_correlation_coefficients = {}  # Initialize an empty dictionary to store max coefficients

for col in df.columns[1:-1]:  # Iterate through all columns except the last one ('medv')
    max_correlation_coefficient = float("-inf")  # Initialize with negative infinity
    for _ in range(1000):  # Run 1000 iterations
        selected_rows = random.sample(range(len(df)), num_rows_to_select)

        col_data = df.loc[selected_rows, col].to_numpy()
        medv_data = df.loc[selected_rows, 'medv'].to_numpy()

        correlation_coefficient, p_value = pearsonr(col_data, medv_data)

        # Update max_correlation_coefficient if a higher value is found
        if correlation_coefficient > max_correlation_coefficient:
            max_correlation_coefficient = correlation_coefficient

    max_correlation_coefficients[column_descriptions[col]] = max_correlation_coefficient

print("Maximum Pearson Correlation Coefficients:")
for col, max_corr in max_correlation_coefficients.items():
    print(f"{col} vs. medv: {max_corr}")
# Out:
# Maximum Pearson Correlation Coefficients:
# Per capita crime rate by town vs. medv: -0.34990817362455645
# Proportion of residential land zoned for large lots vs. medv: 0.4087586255589883
# Proportion of non-retail business acres per town vs. medv: -0.44836349492964833
# Charles River dummy variable (1 if tract bounds river, 0 otherwise) vs. medv: 0.22310425293548566
# Nitrogen oxide concentration (parts per 10 million) vs. medv: -0.3955714720367194
# Average number of rooms per dwelling vs. medv: 0.746485048195819
# Proportion of owner-occupied units built before 1940 vs. medv: -0.3326480283488909
# Weighted distance to employment centers vs. medv: 0.3315624314570561
# Index of accessibility to radial highways vs. medv: -0.3427091145039667
# Property tax rate vs. medv: -0.43497784534689865
# Pupil-teacher ratio vs. medv: -0.4594599714143106
# Proportion of residents of African American descent vs. medv: 0.35827930593796686
# ...

# %%
num_rows_to_select = int(len(df) * 1)
random.seed(42)  # Set a seed for reproducibility

max_correlation_coefficients = {}  # Initialize an empty dictionary to store max coefficients

for col in df.columns[1:-1]:  # Iterate through all columns except the last one ('medv')
    max_correlation_coefficient = float("-inf")  # Initialize with negative infinity
    for _ in range(1000):  # Run 1000 iterations
        selected_rows = random.sample(range(len(df)), num_rows_to_select)

        col_data = df.loc[selected_rows, col].to_numpy()
        medv_data = df.loc[selected_rows, 'medv'].to_numpy()

        correlation_coefficient, p_value = pearsonr(col_data, medv_data)

        # Update max_correlation_coefficient if a higher value is found
        if correlation_coefficient > max_correlation_coefficient:
            max_correlation_coefficient = correlation_coefficient

    max_correlation_coefficients[column_descriptions[col]] = max_correlation_coefficient

print("Maximum Pearson Correlation Coefficients:")
for col, max_corr in max_correlation_coefficients.items():
    print(f"{col} vs. medv: {max_corr}")
# Out:
# Maximum Pearson Correlation Coefficients:
# Per capita crime rate by town vs. medv: -0.38830460858681143
# Proportion of residential land zoned for large lots vs. medv: 0.3604453424505434
# Proportion of non-retail business acres per town vs. medv: -0.48372516002837274
# Charles River dummy variable (1 if tract bounds river, 0 otherwise) vs. medv: 0.17526017719029854
# Nitrogen oxide concentration (parts per 10 million) vs. medv: -0.4273207723732824
# Average number of rooms per dwelling vs. medv: 0.6953599470715397
# Proportion of owner-occupied units built before 1940 vs. medv: -0.37695456500459606
# Weighted distance to employment centers vs. medv: 0.24992873408590405
# Index of accessibility to radial highways vs. medv: -0.3816262306397779
# Property tax rate vs. medv: -0.4685359335677669
# Pupil-teacher ratio vs. medv: -0.5077866855375617
# Proportion of residents of African American descent vs. medv: 0.33346081965706664
# ...

# %%
random.seed(42)  # Set a seed for reproducibility

# Initialize variables to track the maximum correlation
max_correlation = float("-inf")
best_subset_percentage = None

# Iterate through a range of percentages from 0.5 to 0.9
for percentage in range(50, 100, 10): #the range starts at 50, stops before 100, and increments by 10
    num_rows_to_select = int(len(df) * percentage / 100)
    max_corr_for_percentage = float("-inf")  # Initialize with negative infinity

    for col in df.columns[1:-1]:
        max_correlation_coefficient = float("-inf")  # Initialize with negative infinity #to find the maximum value in a series of comparisons

        for _ in range(1000):  # Run 1000 iterations
            selected_rows = random.sample(range(len(df)), num_rows_to_select)

            col_data = df.loc[selected_rows, col].to_numpy()
            medv_data = df.loc[selected_rows, 'medv'].to_numpy()

            correlation_coefficient, p_value = pearsonr(col_data, medv_data)

            if correlation_coefficient > max_correlation_coefficient:
                max_correlation_coefficient = correlation_coefficient

        if max_correlation_coefficient > max_corr_for_percentage:
            max_corr_for_percentage = max_correlation_coefficient

    if max_corr_for_percentage > max_correlation:
        max_correlation = max_corr_for_percentage
        best_subset_percentage = percentage

# Print the subset with the highest correlation
print(f"The subset with the highest correlation with 'medv' is at {best_subset_percentage}% of data.")
print(f"The maximum correlation coefficient is {max_correlation:.2f}")
# Out:
# The subset with the highest correlation with 'medv' is at 50% of data.
# The maximum correlation coefficient is 0.80

# %%
random.seed(42)  # Set a seed for reproducibility

# Initialize variables to track the maximum correlation
max_correlation = float("-inf")
best_subset_percentage = None #to store the corresponding percentage of rows that resulted in the maximum correlation

# Iterate through percentages from 50% to 60%
for percentage in range(50, 61):
    num_rows_to_select = int(len(df) * percentage / 100)
    max_corr_for_percentage = float("-inf")  # Initialize with negative infinity

    for col in df.columns[1:-1]:
        max_correlation_coefficient = float("-inf")  # Initialize with negative infinity

        for _ in range(1000):  # Run 1000 iterations
            selected_rows = random.sample(range(len(df)), num_rows_to_select)

            col_data = df.loc[selected_rows, col].to_numpy()
            medv_data = df.loc[selected_rows, 'medv'].to_numpy()

            correlation_coefficient, p_value = pearsonr(col_data, medv_data)

            if correlation_coefficient > max_correlation_coefficient:
                max_correlation_coefficient = correlation_coefficient

        if max_correlation_coefficient > max_corr_for_percentage:
            max_corr_for_percentage = max_correlation_coefficient

    if max_corr_for_percentage > max_correlation:
        max_correlation = max_corr_for_percentage
        best_subset_percentage = percentage

# Print the subset with the highest correlation
print(f"The subset with the highest correlation with 'medv' between 50% and 60% of data is at {best_subset_percentage}% of data.")
print(f"The maximum correlation coefficient is {max_correlation:.2f}")
# Out:
# The subset with the highest correlation with 'medv' between 50% and 60% of data is at 58% of data.
# The maximum correlation coefficient is 0.81
